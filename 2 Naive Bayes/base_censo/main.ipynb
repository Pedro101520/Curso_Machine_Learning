# %%
import pickle
from sklearn.naive_bayes import GaussianNB

# %%
with open(r'D:\Biblioteca\Documents\Machine_Learning\1 pre_processamento_dados\base_final\censu.pkl', 'rb') as f:
    X_census_treinamento, y_census_treinamento, X_census_teste, y_census_teste = pickle.load(f)

# %%
naive_census = GaussianNB()
naive_census.fit(X_census_treinamento, y_census_treinamento)
previsoes = naive_census.predict(X_census_teste)
previsoes
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '>50K', '<=50K', '>50K'],
#       dtype='<U5')

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# AS vezes não exectutar o escalonamento pode aumentar a acurácia
accuracy_score(y_census_teste, previsoes)
# Out:
# 0.5091095189355169

# %%
confusion_matrix(y_census_teste, previsoes)
# Out:
# array([[1365, 2357],
#        [  41, 1122]])
